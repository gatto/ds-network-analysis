# %% [markdown]
# ### import libraries

# %%
#per creare rete
import pandas as pd
from rich import print
import networkx as nx
import networkx.algorithms as nx
import pandas as pd
import matplotlib.pyplot as plt
from networkx.utils import np_random_state

#per opinion diffusion
import ndlib
import networkx as nx
import ndlib.models.ModelConfig as mc
import ndlib.models.opinions as op

#altre
import seaborn as sns
import numpy as np
import math

# %%
G=nx.read_gexf('final_net.gexf')
df=pd.read_csv('df_final_nodes.csv')

# %%
infected_nodes=[]
for i,c in enumerate(df.category):
    if c=='dontcare' or c=='prorus' or c=='proukr':
        infected_nodes.append(df['node'][i])

# %% [markdown]
# # Opinion diffusion

# %%
model = op.VoterModel(G)
config = mc.Configuration()
config.add_model_parameter('fraction_infected', 0.1) 
#config.add_node_set_configuration('fraction_infected',node_to_value=m.df["class"])

model.set_initial_status(config)

iterations = model.iteration_bunch(1500)
trends = model.build_trends(iterations)

# %%
# %matplotlib inline
from ndlib.viz.mpl.DiffusionTrend import DiffusionTrend
viz = DiffusionTrend(model, trends)
viz.plot()
# Out:
# no display found. Using non-interactive Agg backend
# C:\Users\david\AppData\Local\Programs\Python\Python310\lib\site-packages\ndlib\viz\mpl\DiffusionViz.py:89: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # Majotity vote

# %%
model = op.MajorityRuleModel(G)
config = mc.Configuration()
config.add_model_parameter('q', 5)
config.add_model_parameter('fraction_infected', 0.5)
config.add_model_initial_configuration('fraction_infected',infected_nodes)
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)
trends = model.build_trends(iterations)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21472\1874606846.py in <cell line: 6>()
#       4 config.add_model_parameter('fraction_infected', 0.5)
#       5 config.add_model_initial_configuration('fraction_infected',infected_nodes)
# ----> 6 model.set_initial_status(config)
#       7
#       8 # Simulation execution
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ndlib\models\DiffusionModel.py in set_initial_status(self, configuration)
#     153             self.params['status'][param] = nodes
#     154             for node in nodes:
# --> 155                 self.status[node] = self.available_statuses[param]
#     156
#     157         # Set model additional information
#
# KeyError: 'fraction_infected'

# %%
# %matplotlib inline
from ndlib.viz.mpl.DiffusionTrend import DiffusionTrend
viz = DiffusionTrend(model, trends)
viz.plot()
