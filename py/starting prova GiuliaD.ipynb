# %%
# !pip install -U git+https://github.com/gatto/ds-network-analysis.git
# !pip install -U twarc twarc_csv
from socialetl import SocialETL
# Out:
# ...
#   Cloning https://github.com/gatto/ds-network-analysis.git to /tmp/pip-req-build-tdfdcv60
#   Running command git clone -q https://github.com/gatto/ds-network-analysis.git /tmp/pip-req-build-tdfdcv60
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for twarc-csv: filename=twarc_csv-0.5.2-py3-none-any.whl size=9668 sha256=c343c662e916d3bd408b5be71866ab8268d9add4f021955373e8b0b6f5edd1d8
#   Stored in directory: /root/.cache/pip/wheels/8b/da/29/686e584f0162297399d799af5306e4f559960bafb385ba5755
# Successfully built twarc-csv
# ...

# %%
secret = "AAAAAAAAAAAAAAAAAAAAAGYdbQEAAAAAtcRqZHBE2GLRVi%2BSHABZbdk%2F9LE%3DcCTxuxeY6xledy9Qo3yGzJrvzSIUeLTweQaoMk1Qoh6la767M9"
m = SocialETL(secret=secret, query="putin lang:en -is:retweet")
# this is using the query "slavaukraini"

# %%
m.df
# Out:
#                     id      conversation_id referenced_tweets.replied_to.id  \
# 0  1522509999334998021  1522509999334998021                             NaN
# 1  1522509804799143936  1522509804799143936                             NaN
# 2  1522509761119649792  1522509761119649792                             NaN
# 3  1522509738004692993  1522509738004692993                             NaN
# 4  1522509568689025024  1522509568689025024                             NaN
# 5  1522509564931080192  1522509564931080192                             NaN
# 6  1522509479253839877  1522509479253839877                             NaN
# 7  1522509304640720898  1522509304640720898                             NaN
# 8  1522509274643058688  1522500526134505473             1522500526134505473
# 9  1522509238882422785  1522509238882422785                             NaN
#
#   referenced_tweets.retweeted.id referenced_tweets.quoted.id  \
# 0                            NaN         1522509006669074433
# ...

# %%
m.df["text"]
# Out:
# 0    Makarov's sailors new song\n\nWe'll all live i...
# 1    Fedir Shandor, PhD, Uzhgorod National Universi...
# 2    🐾 I am furry pupset and can’t enjoy this beaut...
# 3    Fedir Shandor, PhD, Uzhgorod National Universi...
# 4    #Germany is supplying #Ukraine with seven armo...
# 5    Fedir Shandor, PhD, Uzhgorod National Universi...
# 6          #dogs #SlavaUkraini https://t.co/MR9j7S77mn
# 7    Fedir Shandor, PhD, Uzhgorod National Universi...
# 8    @TheDeadDistrict If your enemy refuses to go t...
# 9    No puede ser!!! 🤦🏻‍♂️🤦🏻‍♂️🤦🏻‍♂️\nSi se confirm...
# Name: text, dtype: object

# %%
m.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 74 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     10 non-null     object
#  1   conversation_id                        10 non-null     object
#  2   referenced_tweets.replied_to.id        1 non-null      object
#  3   referenced_tweets.retweeted.id         5 non-null      object
#  4   referenced_tweets.quoted.id            3 non-null      object
#  5   author_id                              10 non-null     object
#  6   in_reply_to_user_id                    1 non-null      object
#  7   retweeted_user_id                      5 non-null      object
#  8   quoted_user_id                         3 non-null      object
#  9   created_at                             10 non-null     object
# ...

# %%
one_tweet = m.df.loc[1, "text"]
print(one_tweet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d29ef7c08878> in <module>()
# ----> 1 one_tweet = m.df.loc[1, "text"]
#       2 print(one_tweet)
#
# NameError: name 'm' is not defined

# %%
ukr_hashtag = ["#istandwithukraine","#standwithukraine","#standwithukr","#supportukraine","#supportukr","#slavaukraini",
               "#slavaukraine","#stopputin","#putinisawarcriminal","#armukrainenow","#ukrainewillwin","#russianwarcrimes",
               "#ukrainianswillresist"]
rus_hashtag = ["#istandwithrussia","#istandwithputin"]
pax_hashtag = ["#stopthewar","#stopwar","#peace","#noweapons"]

hashtag_list = ukr_hashtag+rus_hashtag+pax_hashtag

def my_filter(one_tweet) -> bool:
    # todo this function that takes one tweet and returns if we want it or not
    if any (hashtag in one_tweet.lower() for hashtag in hashtag_list):  ## this must be a condition that we want the tweet
        return True
    else:
        return False


for any_tweet in timeline_of_tweets:
    if my_filter(any_tweet):
        my_store(any_tweet)
    else:
        continue


def characterize_tweet(one_tweet):
    my_categories = ("ukr", "rus", "pax", "nocare")

    ## todo this function that takes one tweet and returns a category
    if any (hashtag in one_tweet.lower() for hashtag in ukr_hashtag):
        return my_categories[0]
    elif any (hashtag in one_tweet.lower() for hashtag in rus_hashtag): 
        return my_categories[1]
    elif any (hashtag in one_tweet.lower() for hashtag in pax_hashtag): 
        return my_categories[2]
    else:
        return my_categories[3]


m.df = m.df.apply(characterize_tweet)
