# %%
import pandas as pd
from extract import Count, SocialETL, SocialDB
from rich import print
import networkx as nx
#import networkx.algorithms as nx
import pandas as pd
import matplotlib.pyplot as plt
from networkx.utils import np_random_state
from networkx.algorithms import community
import seaborn as sns
import numpy as np
import math

# %%
m = SocialDB(100)

# %%
m.df
# Out:
#          class
# id
# 195406     pax
# 783149  prorus
# 287779     pax
# 417880     pax
# 529607     pax
# ...        ...
# 556874     pax
# 545344     pax
# 187597  nocare
# 724477     pax
# 650892  prorus
#
# [100 rows x 1 columns]

# %%
m.edges
# Out:
# [{'id': 492080, 'from': 219339, 'to': 479328},
#  {'id': 797000, 'from': 121682, 'to': 912505},
#  {'id': 343686, 'from': 580048, 'to': 417880},
#  {'id': 265366, 'from': 650042, 'to': 983273},
#  {'id': 496828, 'from': 740641, 'to': 706761},
#  {'id': 661902, 'from': 483739, 'to': 573872},
#  {'id': 882013, 'from': 887982, 'to': 820103},
#  {'id': 572044, 'from': 337890, 'to': 704970},
#  {'id': 520541, 'from': 969132, 'to': 556874},
#  {'id': 948558, 'from': 121682, 'to': 803713},
#  {'id': 479944, 'from': 483739, 'to': 121682},
#  {'id': 642770, 'from': 524989, 'to': 135649},
#  {'id': 159426, 'from': 998987, 'to': 135649},
#  {'id': 794750, 'from': 331331, 'to': 347941},
#  {'id': 428292, 'from': 630428, 'to': 141862},
#  {'id': 145341, 'from': 742417, 'to': 355490},
#  {'id': 767828, 'from': 213167, 'to': 251819},
#  {'id': 511849, 'from': 624080, 'to': 219339},
#  {'id': 821172, 'from': 715702, 'to': 251789},
#  {'id': 918683, 'from': 724477, 'to': 331331},
# ...

# %%
g= list(m.df.index)
G = nx.Graph()
G.add_nodes_from(g, stand=m.df["class"])
G.nodes[195406]["stand"]
# Out:
# id
# 195406       pax
# 783149    prorus
# 287779       pax
# 417880       pax
# 529607       pax
#            ...
# 556874       pax
# 545344       pax
# 187597    nocare
# 724477       pax
# 650892    prorus
# Name: class, Length: 100, dtype: category
# Categories (4, object): ['nocare', 'pax', 'prorus', 'proukr']

# %%
edges = [(x["from"], x["to"]) for x in m.edges]
print(edges)
# Out:
# [
#     (219339, 479328),
#     (121682, 912505),
#     (580048, 417880),
#     (650042, 983273),
#     (740641, 706761),
#     (483739, 573872),
#     (887982, 820103),
#     (337890, 704970),
#     (969132, 556874),
#     (121682, 803713),
#     (483739, 121682),
#     (524989, 135649),
#     (998987, 135649),
#     (331331, 347941),
#     (630428, 141862),
#     (742417, 355490),
#     (213167, 251819),
#     (624080, 219339),
#     (715702, 251789),
#     (724477, 331331),
#     (922208, 340144),
#     (347941, 887982),
#     (983273, 655899),
#     (820103, 153450),
#     (724477, 457847),
#     (641073, 483739),
#     (803713, 650892),
#     (769514, 735063),
#     (337890, 855191),
#     (650892, 471657),
#     (803713, 769514),
#     (529607, 195406),
#     (153450, 820103),
#     (803713, 331331),
#     (141862, 889453),
#     (110230, 528611),
#     (998987, 887982),
#     (735063, 573872),
#     (998987, 149776),
#     (715702, 266088),
#     (655899, 592574),
# ...

# %%
G.add_edges_from(edges)

# %%
G.number_of_edges()
# Out:
# 294

# %%
G.number_of_nodes()
# Out:
# 100

# %%
nx.draw(G)

# %%
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :])
Gcc_G = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0])
pos = nx.spring_layout(Gcc_G, seed=10396953)
nx.draw_networkx_nodes(Gcc_G, pos, ax=ax0, node_size=20)
nx.draw_networkx_edges(Gcc_G, pos, ax=ax0, alpha=0.4)
ax0.set_title("Connected components of G")
ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

fig.tight_layout()
plt.show()

# %% [raw]
# #WATTS STROGATS and CONFIGURATION MODEL TO DO
#
# Degree distribution analysis
# Connected components analysis
# Path analysis
# Clustering Coefficient
# Density analysis
# Centrality analysis

# %% [markdown]
# ### Create an Erdons Renyi Random Graph

# %%
er = nx.erdos_renyi_graph(n = 100, p= 0.2, seed = 21)

# %%
degree_sequence = sorted((d for n, d in er.degree()), reverse=True)
dmax_er = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :])
Gcc_e = er.subgraph(sorted(nx.connected_components(er), key=len, reverse=True)[0])
pos = nx.spring_layout(Gcc_e, seed=21)
nx.draw_networkx_nodes(Gcc_e, pos, ax=ax0, node_size=20)
nx.draw_networkx_edges(Gcc_e, pos, ax=ax0, alpha=0.4)
ax0.set_title("Connected components of G")
ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Create an Barabasi Albert Graph

# %%
ba = nx.barabasi_albert_graph(n = 100, m =6 , seed = 21)

# %%
degree_sequence = sorted((d for n, d in ba.degree()), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :])
Gcc_b = ba.subgraph(sorted(nx.connected_components(ba), key=len, reverse=True)[0])
pos = nx.spring_layout(Gcc_b, seed=10396953)
nx.draw_networkx_nodes(Gcc_b, pos, ax=ax0, node_size=20)
nx.draw_networkx_edges(Gcc_b, pos, ax=ax0, alpha=0.4)
ax0.set_title("Connected components of G")
ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

fig.tight_layout()
plt.show()
